# %%
from src.features.engineering import FeatureEngineer

engineer = FeatureEngineer(data_dir="data/processed")

X, y, project_split = engineer.create_feature_matrix()

feature_names = engineer.get_feature_names()

summary = engineer.get_feature_summary()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.features.engineering import FeatureEngineer
#       2
#       3 engineer = FeatureEngineer(data_dir="data/processed")
#       4
#
# ImportError: cannot import name 'FeatureEngineer' from 'src.features.engineering' (d:\AI Construction\src\features\engineering.py)

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

print("Project root:", project_root)
# Out:
# Project root: d:\AI Construction

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# %%
from src.features.engineering import FeatureEngineer

engineer = FeatureEngineer(data_dir="../data/raw")
X, y, project_split = engineer.create_feature_matrix()

feature_names = engineer.get_feature_names()
summary = engineer.get_feature_summary()

print("Feature matrix shape:", X.shape)
print("Target shape:", y.shape)
print("Number of features:", len(feature_names))

display(summary)
# Out:
# Feature matrix shape: (9279, 64)
# Target shape: (9279,)
# Number of features: 64
#                        feature    dtype
# 0        planned_duration_days  numeric
# 1                     quantity  numeric
# 2                    unit_cost  numeric
# 3                 planned_cost  numeric
# 4                  criticality  numeric
# ..                         ...      ...
# 59       project_type_Hospital  numeric
# 60     project_type_Industrial  numeric
# 61  project_type_Institutional  numeric
# 62    project_type_Residential  numeric
# 63            project_type_nan  numeric
#
# [64 rows x 2 columns]

# %%
from pathlib import Path

print("Current notebook folder:")
print(Path.cwd())

print("\nData folder exists:")
print(Path("data/raw").exists())

print("\nFiles found:")
for file in Path("data/raw").glob("*.csv"):
    print(file)
# Out:
# Current notebook folder:
# d:\AI Construction\notebooks
#
# Data folder exists:
# False
#
# Files found:
